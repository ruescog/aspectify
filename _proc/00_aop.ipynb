# %% [raw]
# ---
# description: Apply Aspect Oriented Programming to your Python code
# output-file: aop.html
# title: aop
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(is_detectable)
# Out:
# ---
#
# [source](https://github.com/ruescog/aspectify/blob/main/aspectify/aop.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### is_detectable
#
# >      is_detectable (name, obj)
#
# Determines when an object is potentially detectable to add an aspect to it.
#
# Params:
# name: str ; The name of the object.
# obj: object ; The builded object --generaly a class--.
#
# Returns:
# b: boolean ; Whether the `obj` object (so called `name`) is detectable via AOP or not.

# %%
#| echo: false
#| output: asis
show_doc(advice)
# Out:
# ---
#
# [source](https://github.com/ruescog/aspectify/blob/main/aspectify/aop.py#L28){target="_blank" style="float:right; font-size:smaller"}
#
# ### advice
#
# >      advice (moment, todo)
#
# Add an advice to a particular function.
#
# Params:
# moment: str ; One of 'before', 'around', 'after_returning', 'after_throwing' or 'after'. See the documentation for more information.
# todo: funtion ; What to do at the selected moment.
#
# Returns:
# dec: function ; The modified function.

# %%
#| echo: false
#| output: asis
show_doc(Aspect)
# Out:
# ---
#
# [source](https://github.com/ruescog/aspectify/blob/main/aspectify/aop.py#L59){target="_blank" style="float:right; font-size:smaller"}
#
# ### Aspect
#
# >      Aspect (name)
#
# Defines a complete aspect.
